# %% [markdown]
# Exam 3 (Deadline 19th November)

# %% [markdown]
# # A. Predicting Price Direction [34 marks]

# %% [markdown]
# Unpredictability of short-term asset returns is a subject of asset pricing research: efficient markets produce
# near-Normal daily returns with low correlation to past values. That limits application of autoregression
# on lagged returns. However, the progress is possible and in this assignment you will make direction
# predictions using any 2 out of 4 types of Classifier of your choice.
#
#
# Predict sign of next daily move but welcome to modify the task to predict for longer periods, a 5-day
# move. Certain classiers SVM, ANN are more suited to make such longer-term predictions.

# %%
from IPython.display import Image
Image("image1.PNG")

# %% [markdown]
# ## Study Design:

# %% [markdown]
# ## Classifier A.1 Logistic Classifier and Bayesian Classifier
#
#
# a) Make sure to implement penalised versions of logistic regression and discuss impact on coefficients.
# Apply and discuss the difference between L1 and L2 cost functions, the impact made on regression coefficients. b) Demonstrate the use of sklearn.model selection for reshuffled samples and k-fold crossvalidation.

# %%
import pandas as pd
#C:\Users\stefano.spillo\OneDrive - IHS Markit\CQF Exam 3

df = pd.read_excel("File.xlsx", sheet_name="Data")

returns_SPX = pd.read_excel("File.xlsx", usecols=[2])
returns_Nikkei = pd.read_excel("File.xlsx", sheet_name = "Nikkei_Features", usecols=[4])

import os	
os.getcwd()
# Out:
# 'C:\\Users\\stefano.spillo\\OneDrive - IHS Markit\\CQF Exam 3'

# %%
from sklearn import linear_model
logit = linear_model.LogisticRegression(C=1e5)
logit.fit(X_Features, Y_Response) ###FITTING DONE HERE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-ec52d4c56ab7> in <module>
#       1 from sklearn import linear_model
#       2 logit = linear_model.LogisticRegression(C=1e5)
# ----> 3 logit.fit(X_Features, Y_Response) ###FITTING DONE HERE
#
# NameError: name 'X_Features' is not defined

# %%
import numpy
returns_Nikkei = pd.read_excel("File.xlsx", sheet_name = "Nikkei_Features", usecols=[0,1,2,3],skiprows=[1])

# %%
returns_Nikkei_ravel = numpy.ravel(returns_Nikkei )

# %%
returns_Nikkei.Direction
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 480    1
# 481    1
# 482    1
# 483    1
# 484    0
# Name: Direction, Length: 485, dtype: int64

# %%
print(returns_Nikkei_ravel)
# Out:
# [Timestamp('2018-01-02 00:00:00') 22764.94 0.0 ... 23331.84
#  -0.0025695747632229374 0]

# %% [markdown]
# ## Question R.1

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.preprocessing import StandardScaler

# %%
digits = datasets.load_digits()

# %% [markdown]
# Question R.1 Consider specification for a plain Interest Rate Swap:
# oating payment frequency is 6M, and the rate is set six months before payment (swaplet) date. The swap
# expires in 5 years, and payments occur every six months on principal of $1. Zero-coupon
# bond prices are known for all reset points, denote them Z(t; i
# 2 ) where i is period counter.
# For the $$r_st$$ six-month period, payment is made at end and discounted with Z(t; 1
# 2 ).

# %%
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # R. Interest Rate Modeling [10 marks each]

# %% [markdown]
# Question R.1 Consider specication for a plain Interest Rate Swap:
# oating payment
# frequency is 6M, and the rate is set six months before payment (swaplet) date. The swap
# expires in 5 years, and payments occur every six months on principal of $1. Zero-coupon
# bond prices are known for all reset points, denote them Z(t; i
# 2 ) where i is period counter.
# For the rst six-month period, payment is made at end and discounted with Z(t; 1
# 2 ).
# Derive analytical formula for the fair level of xed rate rs, so that initially the swap has
# no value. Should be given as an algebraic expression.

# %%
# Point Allocation
A_Predicting_Price_Direction = 34
B_Prediction_Quality_and_Bias = 36
R_Interest_Rate_Modelling = 30

Total_Points = A_Predicting_Price_Direction + B_Prediction_Quality_and_Bias + R_Interest_Rate_Modelling
print(Total_Points)
# Out:
# 100

# %% [markdown]
# install packages:
#
#      conda install -c anaconda pandas-datareader

# %% [markdown]
# References and Resources:
#
#
#     https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html
